# %%
pip install streamlit pandas plotly
# Out:
# Collecting streamlit
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
# Requirement already satisfied: pandas in c:\users\vijaya\anaconda3\lib\site-packages (1.1.3)
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Requirement already satisfied: packaging<25,>=20 in c:\users\vijaya\anaconda3\lib\site-packages (from streamlit) (20.4)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)Note: you may need to restart the kernel to use updated packages.
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# streamlit 1.40.1 requires pandas<3,>=1.4.0, but you'll have pandas 1.1.3 which is incompatible.
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting typing-extensions<5,>=4.3.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting watchdog<7,>=2.1.5; platform_system != "Darwin"
#   Downloading watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\vijaya\anaconda3\lib\site-packages (from streamlit) (6.0.4)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\vijaya\anaconda3\lib\site-packages (from streamlit) (0.10.1)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting numpy<3,>=1.20
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Collecting protobuf<6,>=3.20
#   Downloading protobuf-5.29.1-cp38-cp38-win_amd64.whl (434 kB)
# Collecting requests<3,>=2.27
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting altair<6,>=4.0
#   Downloading altair-5.4.1-py3-none-any.whl (658 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\vijaya\anaconda3\lib\site-packages (from streamlit) (8.0.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\vijaya\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\vijaya\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vijaya\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six in c:\users\vijaya\anaconda3\lib\site-packages (from packaging<25,>=20->streamlit) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vijaya\anaconda3\lib\site-packages (from packaging<25,>=20->streamlit) (2.4.7)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\vijaya\anaconda3\lib\site-packages (from pydeck<1,>=0.8.0b4->streamlit) (2.11.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijaya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vijaya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.25.11)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.0-cp38-cp38-win_amd64.whl (101 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijaya\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2020.6.20)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vijaya\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.2.0)
# Collecting narwhals>=1.5.2
#   Downloading narwhals-1.18.3-py3-none-any.whl (250 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vijaya\anaconda3\lib\site-packages (from jinja2>=2.10.1->pydeck<1,>=0.8.0b4->streamlit) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vijaya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vijaya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\vijaya\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (50.3.1.post20201107)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: cachetools, typing-extensions, pygments, mdurl, markdown-it-py, rich, numpy, pydeck, watchdog, pyarrow, blinker, protobuf, charset-normalizer, requests, narwhals, altair, smmap, gitdb, gitpython, tenacity, streamlit, plotly
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.7.2
#     Uninstalling Pygments-2.7.2:
#       Successfully uninstalled Pygments-2.7.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
#   Attempting uninstall: watchdog
#     Found existing installation: watchdog 0.10.3
#     Uninstalling watchdog-0.10.3:
#       Successfully uninstalled watchdog-0.10.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# Successfully installed altair-5.4.1 blinker-1.8.2 cachetools-5.5.0 charset-normalizer-3.4.0 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.18.3 numpy-1.24.4 plotly-5.24.1 protobuf-5.29.1 pyarrow-17.0.0 pydeck-0.9.1 pygments-2.18.0 requests-2.32.3 rich-13.9.4 smmap-5.0.1 streamlit-1.40.1 tenacity-9.0.0 typing-extensions-4.12.2 watchdog-4.0.2

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Load the dataset
data_path = "C:/Users/VIJAYA/Downloads/vgsales.csv"  # Update with your dataset path
data = pd.read_csv(data_path)

# Clean and preprocess the data
data.dropna(subset=["Year", "Publisher"], inplace=True)
data["Year"] = data["Year"].astype(int)

# Sidebar Filters
st.sidebar.header("Filters")
genre_filter = st.sidebar.multiselect("Select Genre", data["Genre"].unique(), default=data["Genre"].unique())
platform_filter = st.sidebar.multiselect("Select Platform", data["Platform"].unique(), default=data["Platform"].unique())
year_filter = st.sidebar.slider("Select Year Range", int(data["Year"].min()), int(data["Year"].max()), (2000, 2015))

# Filter data based on selections
filtered_data = data[
    (data["Genre"].isin(genre_filter)) &
    (data["Platform"].isin(platform_filter)) &
    (data["Year"].between(year_filter[0], year_filter[1]))
]

# Main Dashboard
st.title("Video Game Sales Dashboard")
st.markdown("Explore trends, sales, and insights in the video game industry.")

# Key Performance Indicators
st.header("Key Metrics")
total_sales = filtered_data["Global_Sales"].sum()
top_genre = filtered_data.groupby("Genre")["Global_Sales"].sum().idxmax()
top_game = filtered_data.loc[filtered_data["Global_Sales"].idxmax(), "Name"]

st.metric("Total Global Sales", f"{total_sales:.2f} million")
st.metric("Top Genre", top_genre)
st.metric("Best-Selling Game", top_game)

# Sales Trends by Year
st.header("Sales Trends by Year")
sales_by_year = filtered_data.groupby("Year")["Global_Sales"].sum().reset_index()
fig1 = px.line(sales_by_year, x="Year", y="Global_Sales", title="Global Sales Over the Years")
st.plotly_chart(fig1)

# Average Sales by Genre
st.header("Average Sales by Genre")
avg_sales_genre = filtered_data.groupby("Genre")["Global_Sales"].mean().reset_index()
fig2 = px.bar(avg_sales_genre, x="Genre", y="Global_Sales", title="Average Sales by Genre", color="Genre")
st.plotly_chart(fig2)

# Correlation Heatmap
st.header("Correlation Analysis")
sales_columns = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]
correlation = filtered_data[sales_columns].corr()
fig3 = px.imshow(correlation, text_auto=True, title="Correlation Heatmap")
st.plotly_chart(fig3)

# Top Publishers
st.header("Top Publishers by Number of Games")
top_publishers = (
    filtered_data.groupby("Publisher")["Name"].count().reset_index().sort_values("Name", ascending=False).head(10)
)
fig4 = px.bar(top_publishers, x="Publisher", y="Name", title="Top Publishers by Number of Games")
st.plotly_chart(fig4)

# Footer
st.sidebar.markdown("---")
st.sidebar.markdown("Developed by Group 21")
# Out:
# 2024-12-14 17:46:24.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:24.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 17:46:25.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())

# %%
streamlit run dashboard.py
# Out:
#   File "<ipython-input-4-5bd035b99858>", line 1
#     streamlit run dashboard.py
#               ^
# SyntaxError: invalid syntax
